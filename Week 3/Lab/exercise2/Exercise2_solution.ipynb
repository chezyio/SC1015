# %% [markdown]
# Problem 1 : Data Preparation
# Check how to import the Pokemon data and perform basic Statistics You will need the CSV data file pokemonData.csv to use this code
# Check how to import the Pokemon data and perform Exploratory Analysis You will need the CSV data file pokemonData.csv to use this code
# Download the dataset train.csv and the associated text file data_description.txt posted with this Exercise. The dataset and description are collected from Kaggle. You may also want to download the files directly from the Kaggle Competition (Login > Go to “Data” > “Download All”). Either way, read the competition description to get an idea about the task.
# Source : Kaggle Competition : House Prices : https://www.kaggle.com/c/house-prices-advanced-regression-techniques <br/>
# a) Import the “train.csv” data you downloaded (either from NTU Learn or Kaggle) in Jupyter Notebook. <br/>
# b) What are the data types (“dtypes”) – int64/float64/object – of the variables (columns) in the dataset? <br/>
# c) Create a new Pandas DataFrame consisting of only the variables (columns) of type Integer (int64). <br/>
# d) Open the “data_description.txt” file you downloaded (either from NTU Learn or Kaggle) in Wordpad. <br/>
# e) Read the description for each variable carefully and try to identify the “actual” Numeric variables. Categorical variables are often “encoded” as Numeric variables for easy representation. Spot them. <br/>
# f) Drop non-Numeric variables from the DataFrame to have a clean DataFrame with Numeric variables.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
dataset = pd.read_csv('./data/train.csv')
df = pd.DataFrame(dataset)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df_modified = df.select_dtypes(include='int64')
df_modified
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %%
df_modified.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 35 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotArea        1460 non-null   int64
#  3   OverallQual    1460 non-null   int64
#  4   OverallCond    1460 non-null   int64
#  5   YearBuilt      1460 non-null   int64
#  6   YearRemodAdd   1460 non-null   int64
#  7   BsmtFinSF1     1460 non-null   int64
#  8   BsmtFinSF2     1460 non-null   int64
#  9   BsmtUnfSF      1460 non-null   int64
#  10  TotalBsmtSF    1460 non-null   int64
#  11  1stFlrSF       1460 non-null   int64
#  12  2ndFlrSF       1460 non-null   int64
#  13  LowQualFinSF   1460 non-null   int64
#  14  GrLivArea      1460 non-null   int64
#  15  BsmtFullBath   1460 non-null   int64
#  16  BsmtHalfBath   1460 non-null   int64
#  17  FullBath       1460 non-null   int64
# ...

# %%
df_modified.drop(['MSSubClass', 'OverallQual', 'OverallCond', 'BsmtFinSF2'], axis=1)
df_modified
# Out:
#         Id  MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0        1          60     8450            7            5       2003
# 1        2          20     9600            6            8       1976
# 2        3          60    11250            7            5       2001
# 3        4          70     9550            7            5       1915
# 4        5          60    14260            8            5       2000
# ...    ...         ...      ...          ...          ...        ...
# 1455  1456          60     7917            6            5       1999
# 1456  1457          20    13175            6            6       1978
# 1457  1458          70     9042            7            9       1941
# 1458  1459          20     9717            5            6       1950
# 1459  1460          20     9937            5            6       1965
#
#       YearRemodAdd  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  WoodDeckSF  \
# ...

# %% [markdown]
# Problem 2 : Statistical Summary <br/>
# Now that you have a “clean” DataFrame with only Numeric variables, we can safely perform standard statistics.<br/>
# a) Find the Summary Statistics (Mean, Median, Quartiles etc.) of SalePrice from the Numeric DataFrame.<br/>
# b) Visualize the summary statistics and distribution of SalePrice using standard Box-Plot, Histogram, KDE.<br/>
# c) Find the Summary Statistics (Mean, Median, Quartiles etc) of LotArea from the Numeric DataFrame.<br/>
# d) Visualize the summary statistics and distribution of LotArea using standard Box-Plot, Histogram, KDE.<br/>
# e) Plot SalePrice (y-axis) vs LotArea (x-axis) using jointplot and find the Correlation between the two.<br/>

# %%
df_modified['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
sb.boxplot(x=df_modified['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice'>

# %%
sb.histplot(x=df_modified['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %%
sb.kdeplot(x=df_modified['SalePrice'])
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df_modified['LotArea'].describe()
# Out:
# count      1460.000000
# mean      10516.828082
# std        9981.264932
# min        1300.000000
# 25%        7553.500000
# 50%        9478.500000
# 75%       11601.500000
# max      215245.000000
# Name: LotArea, dtype: float64

# %%
sb.boxplot(x=df_modified['LotArea'])
# Out:
# <AxesSubplot:xlabel='LotArea'>

# %%
sb.histplot(df_modified['LotArea'])
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Count'>

# %%
sb.kdeplot(df_modified['LotArea'])
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='Density'>

# %%
sb.jointplot(x=df_modified['LotArea'], y=df_modified['SalePrice'])

# %% [markdown]
# Bonus Problem <br/>
# Create a new Pandas DataFrame consisting of all variables (columns) of type Integer (int64) or Float (float64). Read the description for each variable carefully and try to identify the “actual” Numeric variables in the data. <br/>
#
# Drop non-Numeric variables from the DataFrame to have a clean DataFrame with only the Numeric variables. Plot SalePrice vs each of the Numeric variables you identified to understand their correlation or dependence.

# %%
df_bonus = df.select_dtypes(['int64', 'float64']).drop(['MSSubClass', 'OverallQual', 'OverallCond', 'BsmtFinSF2', 'MoSold', 'YrSold', 'YearBuilt', 'YearRemodAdd'], axis=1)
df_bonus.head(20)
# Out:
#     Id  LotFrontage  LotArea  MasVnrArea  BsmtFinSF1  BsmtUnfSF  TotalBsmtSF  \
# 0    1         65.0     8450       196.0         706        150          856
# 1    2         80.0     9600         0.0         978        284         1262
# 2    3         68.0    11250       162.0         486        434          920
# 3    4         60.0     9550         0.0         216        540          756
# 4    5         84.0    14260       350.0         655        490         1145
# 5    6         85.0    14115         0.0         732         64          796
# 6    7         75.0    10084       186.0        1369        317         1686
# 7    8          NaN    10382       240.0         859        216         1107
# 8    9         51.0     6120         0.0           0        952          952
# 9   10         50.0     7420         0.0         851        140          991
# 10  11         70.0    11200         0.0         906        134         1040
# ...

# %%
list(df_bonus)
# Out:
# ['Id',
#  'LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageYrBlt',
#  'GarageCars',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF',
#  'EnclosedPorch',
#  '3SsnPorch',
#  'ScreenPorch',
#  'PoolArea',
#  'MiscVal',
#  'SalePrice']

# %%
sb.pairplot(data=df_bonus, y_vars=['SalePrice'], x_vars=list(df_bonus))
